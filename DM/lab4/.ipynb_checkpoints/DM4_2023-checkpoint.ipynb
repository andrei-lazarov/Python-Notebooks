# %% [markdown]
# # Part-of-speech tagging
#
# Part-of-speech (POS) tagging is the process of labeling each word in a text corpus with its grammatical category, such as noun, verb, or adjective. POS tagging helps machines understand the structure of text, which is useful for tasks like sentiment analysis or text classification.
#
# In this lab, we will use Python and the pandas library to explore POS tagging techniques and apply them to real-world text data.
#
# Useful nltk PoS documentation - https://www.nltk.org/book/ch05.html

# %%
import nltk
import pandas as pd

# Download the necessary NLTK data
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Sample text
text = "I like to eat pizza and play video games with my friends."

# Tokenize the text
tokens = nltk.word_tokenize(text)

# Perform PoS tagging
pos_tags = nltk.pos_tag(tokens)
pos_tags
# Out:
# [nltk_data] Downloading package punkt to /home/andy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/andy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('I', 'PRP'),
#  ('like', 'VBP'),
#  ('to', 'TO'),
#  ('eat', 'VB'),
#  ('pizza', 'NN'),
#  ('and', 'CC'),
#  ('play', 'VB'),
#  ('video', 'NN'),
#  ('games', 'NNS'),
#  ('with', 'IN'),
#  ('my', 'PRP$'),
#  ('friends', 'NNS'),
#  ('.', '.')]

# %%
# Convert PoS tags to a DataFrame
pos_df = pd.DataFrame(pos_tags, columns=['Word', 'PoS'])
pos_df.head()
# Out:
#     Word  PoS
# 0      I  PRP
# 1   like  VBP
# 2     to   TO
# 3    eat   VB
# 4  pizza   NN

# %%
# Count the frequency of each PoS tag and convert it to a dataframe
counts_df = pos_df.groupby('PoS').size().reset_index(name='Count')
counts_df
# Out:
#     PoS  Count
# 0     .      1
# 1    CC      1
# 2    IN      1
# 3    NN      2
# 4   NNS      2
# 5   PRP      1
# 6  PRP$      1
# 7    TO      1
# 8    VB      2
# 9   VBP      1

# %% [markdown]
# Let's look at Jane Austen's Pride and Prejudice

# %%
import requests
import string
import pandas as pd

# Pride and Prejudice
book_url = 'https://www.gutenberg.org/cache/epub/1342/pg1342.txt'
response = requests.get(book_url)
pride_prejudice = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
pride_prejudice = ''.join(c for c in pride_prejudice if c in allowed_chars)

# Tokenize the text
tokens = nltk.word_tokenize(pride_prejudice)

# Perform PoS tagging
pos_tags = nltk.pos_tag(tokens)
pos_tags
# Out:
# [('The', 'DT'),
#  ('Project', 'NNP'),
#  ('Gutenberg', 'NNP'),
#  ('eBook', 'NN'),
#  ('of', 'IN'),
#  ('Pride', 'NNP'),
#  ('and', 'CC'),
#  ('prejudice', 'NN'),
#  ('by', 'IN'),
#  ('Jane', 'NNP'),
#  ('Austen', 'NNP'),
#  ('This', 'DT'),
#  ('eBook', 'NN'),
#  ('is', 'VBZ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('anyone', 'NN'),
#  ('anywhere', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('and', 'CC'),
#  ('most', 'JJS'),
#  ('other', 'JJ'),
#  ('parts', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('at', 'IN'),
#  ('no', 'DT'),
#  ('cost', 'NN'),
#  ('and', 'CC'),
#  ('with', 'IN'),
#  ('almost', 'RB'),
#  ('no', 'DT'),
#  ('restrictions', 'NNS'),
#  ('whatsoever', 'IN'),
#  ('You', 'PRP'),
#  ('may', 'MD'),
#  ('copy', 'VB'),
#  ('it', 'PRP'),
#  ('give', 'VB'),
#  ('it', 'PRP'),
#  ('away', 'RB'),
#  ('or', 'CC'),
#  ('reuse', 'VB'),
#  ('it', 'PRP'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('terms', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Project', 'NNP'),
#  ('Gutenberg', 'NNP'),
#  ('License', 'NNP'),
#  ('included', 'VBD'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('eBook', 'NN'),
#  ('or', 'CC'),
#  ('online', 'NN'),
#  ('at', 'IN'),
#  ('wwwgutenbergorg', 'NN'),
#  ('If', 'IN'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('located', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('have', 'VB'),
#  ('to', 'TO'),
#  ('check', 'VB'),
#  ('the', 'DT'),
#  ('laws', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('where', 'WRB'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('located', 'VBN'),
#  ('before', 'IN'),
#  ('using', 'VBG'),
#  ('this', 'DT'),
#  ('eBook', 'NN'),
#  ('Title', 'NNP'),
#  ('Pride', 'NNP'),
#  ('and', 'CC'),
#  ('prejudice', 'NN'),
#  ('Author', 'NNP'),
#  ('Jane', 'NNP'),
#  ('Austen', 'NNP'),
#  ('Release', 'NNP'),
#  ('Date', 'NNP'),
#  ('November', 'NNP'),
#  ('12', 'CD'),
#  ('2022', 'CD'),
#  ('eBook', 'NN'),
#  ('1342', 'CD'),
#  ('Most', 'JJS'),
#  ('recently', 'RB'),
#  ('updated', 'VBN'),
#  ('March', 'NNP'),
#  ('14', 'CD'),
#  ('2023', 'CD'),
#  ('Language', 'NNP'),
#  ('English', 'NNP'),
#  ('Produced', 'NNP'),
#  ('by', 'IN'),
#  ('Chuck', 'NNP'),
#  ('Greif', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Online', 'NNP'),
#  ('Distributed', 'NNP'),
#  ('Proofreading', 'NNP'),
#  ('Team', 'NNP'),
#  ('at', 'IN'),
#  ('httpwwwpgdpnet', 'NN'),
#  ('This', 'DT'),
#  ('file', 'NN'),
#  ('was', 'VBD'),
#  ('produced', 'VBN'),
#  ('from', 'IN'),
#  ('images', 'NNS'),
#  ('available', 'JJ'),
#  ('at', 'IN'),
#  ('The', 'DT'),
#  ('Internet', 'NNP'),
#  ('Archive', 'NNP'),
#  ('START', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('PROJECT', 'NNP'),
#  ('GUTENBERG', 'NNP'),
#  ('EBOOK', 'NNP'),
#  ('PRIDE', 'NNP'),
#  ('AND', 'NNP'),
#  ('PREJUDICE', 'NNP'),
#  ('Illustration', 'NNP'),
#  ('GEORGE', 'NNP'),
#  ('ALLEN', 'NNP'),
#  ('PUBLISHER', 'NNP'),
#  ('156', 'CD'),
#  ('CHARING', 'NNP'),
#  ('CROSS', 'NNP'),
#  ('ROAD', 'NNP'),
#  ('LONDON', 'NNP'),
#  ('RUSKIN', 'NNP'),
#  ('HOUSE', 'NNP'),
#  ('Illustration', 'NNP'),
#  ('Reading', 'NNP'),
#  ('Janes', 'NNP'),
#  ('Letters', 'NNP'),
#  ('Chap', 'NNP'),
#  ('34', 'CD'),
#  ('PRIDE', 'NNP'),
#  ('and', 'CC'),
#  ('PREJUDICE', 'NNP'),
#  ('by', 'IN'),
#  ('Jane', 'NNP'),
#  ('Austen', 'NNP'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('Preface', 'NN'),
#  ('by', 'IN'),
#  ('George', 'NNP'),
#  ('Saintsbury', 'NNP'),
#  ('and', 'CC'),
#  ('Illustrations', 'NNP'),
#  ('by', 'IN'),
#  ('Hugh', 'NNP'),
#  ('Thomson', 'NNP'),
#  ('Illustration', 'NNP'),
#  ('1894', 'CD'),
#  ('Ruskin', 'NNP'),
#  ('156', 'CD'),
#  ('Charing', 'NNP'),
#  ('House', 'NNP'),
#  ('Cross', 'NNP'),
#  ('Road', 'NNP'),
#  ('London', 'NNP'),
#  ('George', 'NNP'),
#  ('Allen', 'NNP'),
#  ('CHISWICK', 'NNP'),
#  ('PRESSCHARLES', 'NNP'),
#  ('WHITTINGHAM', 'NNP'),
#  ('AND', 'NNP'),
#  ('CO', 'NNP'),
#  ('TOOKS', 'NNP'),
#  ('COURT', 'NNP'),
#  ('CHANCERY', 'NNP'),
#  ('LANE', 'NNP'),
#  ('LONDON', 'NNP'),
#  ('Illustration', 'NNP'),
#  ('To', 'TO'),
#  ('J', 'NNP'),
#  ('Comyns', 'NNP'),
#  ('Carr', 'NNP'),
#  ('in', 'IN'),
#  ('acknowledgment', 'NN'),
#  ('of', 'IN'),
#  ('all', 'DT'),
#  ('I', 'PRP'),
#  ('owe', 'VBP'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('friendship', 'NN'),
#  ('and', 'CC'),
#  ('advice', 'NN'),
#  ('these', 'DT'),
#  ('illustrations', 'NNS'),
#  ('are', 'VBP'),
#  ('gratefully', 'RB'),
#  ('inscribed', 'VBN'),
#  ('Hugh', 'NNP'),
#  ('Thomson', 'NNP'),
#  ('PREFACE', 'NNP'),
#  ('Illustration', 'NNP'),
#  ('Walt', 'NNP'),
#  ('Whitman', 'NNP'),
#  ('has', 'VBZ'),
#  ('somewhere', 'RB'),
#  ('a', 'DT'),
#  ('fine', 'JJ'),
#  ('and', 'CC'),
#  ('just', 'RB'),
#  ('distinction', 'NN'),
#  ('between', 'IN'),
#  ('loving', 'VBG'),
#  ('by', 'IN'),
#  ('allowance', 'NN'),
#  ('and', 'CC'),
#  ('loving', 'NN'),
#  ('with', 'IN'),
#  ('personal', 'JJ'),
#  ('love', 'NN'),
#  ('This', 'DT'),
#  ('distinction', 'NN'),
#  ('applies', 'VBZ'),
#  ('to', 'TO'),
#  ('books', 'NNS'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('to', 'TO'),
#  ('men', 'NNS'),
#  ('and', 'CC'),
#  ('women', 'NNS'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('case', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('not', 'RB'),
#  ('very', 'RB'),
#  ('numerous', 'JJ'),
#  ('authors', 'NNS'),
#  ('who', 'WP'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('objects', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('personal', 'JJ'),
#  ('affection', 'NN'),
#  ('it', 'PRP'),
#  ('brings', 'VBZ'),
#  ('a', 'DT'),
#  ('curious', 'JJ'),
#  ('consequence', 'NN'),
#  ('with', 'IN'),
#  ('it', 'PRP'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('much', 'RB'),
#  ('more', 'JJR'),
#  ('difference', 'NN'),
#  ('as', 'IN'),
#  ('to', 'TO'),
#  ('their', 'PRP$'),
#  ('best', 'JJS'),
#  ('work', 'NN'),
#  ('than', 'IN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('case', 'NN'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('others', 'NNS'),
#  ('who', 'WP'),
#  ('are', 'VBP'),
#  ('loved', 'VBN'),
#  ('by', 'IN'),
#  ('allowance', 'NN'),
#  ('by', 'IN'),
#  ('convention', 'NN'),
#  ('and', 'CC'),
#  ('because', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('felt', 'VBN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('right', 'NN'),
#  ('and', 'CC'),
#  ('proper', 'JJ'),
#  ('thing', 'NN'),
#  ('to', 'TO'),
#  ('love', 'VB'),
#  ('them', 'PRP'),
#  ('And', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('sectfairly', 'JJ'),
#  ('large', 'JJ'),
#  ('and', 'CC'),
#  ('yet', 'RB'),
#  ('unusually', 'RB'),
#  ('choiceof', 'JJ'),
#  ('Austenians', 'NNPS'),
#  ('or', 'CC'),
#  ('Janites', 'NNPS'),
#  ('there', 'RB'),
#  ('would', 'MD'),
#  ('probably', 'RB'),
#  ('be', 'VB'),
#  ('found', 'VBN'),
#  ('partisans', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('claim', 'NN'),
#  ('to', 'TO'),
#  ('primacy', 'NN'),
#  ('of', 'IN'),
#  ('almost', 'RB'),
#  ('every', 'DT'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('novels', 'NNS'),
#  ('To', 'TO'),
#  ('some', 'DT'),
#  ('the', 'DT'),
#  ('delightful', 'JJ'),
#  ('freshness', 'NN'),
#  ('and', 'CC'),
#  ('humour', 'NN'),
#  ('of', 'IN'),
#  ('Northanger', 'NNP'),
#  ('Abbey', 'NNP'),
#  ('its', 'PRP$'),
#  ('completeness', 'NN'),
#  ('finish', 'NN'),
#  ('and', 'CC'),
#  ('entrain', 'VB'),
#  ('obscure', 'JJ'),
#  ('the', 'DT'),
#  ('undoubted', 'JJ'),
#  ('critical', 'JJ'),
#  ('facts', 'NNS'),
#  ('that', 'IN'),
#  ('its', 'PRP$'),
#  ('scale', 'NN'),
#  ('is', 'VBZ'),
#  ('small', 'JJ'),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('scheme', 'NN'),
#  ('after', 'IN'),
#  ('all', 'DT'),
#  ('that', 'DT'),
#  ('of', 'IN'),
#  ('burlesque', 'NN'),
#  ('or', 'CC'),
#  ('parody', 'NN'),
#  ('a', 'DT'),
#  ('kind', 'NN'),
#  ('in', 'IN'),
#  ('which', 'WDT'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('rank', 'NN'),
#  ('is', 'VBZ'),
#  ('reached', 'VBN'),
#  ('with', 'IN'),
#  ('difficulty', 'NN'),
#  ('Persuasion', 'NNP'),
#  ('relatively', 'RB'),
#  ('faint', 'NN'),
#  ('in', 'IN'),
#  ('tone', 'NN'),
#  ('and', 'CC'),
#  ('not', 'RB'),
#  ('enthralling', 'VBG'),
#  ('in', 'IN'),
#  ('interest', 'NN'),
#  ('has', 'VBZ'),
#  ('devotees', 'NNS'),
#  ('who', 'WP'),
#  ('exalt', 'VBP'),
#  ('above', 'IN'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('others', 'NNS'),
#  ('its', 'PRP$'),
#  ('exquisite', 'JJ'),
#  ('delicacy', 'NN'),
#  ('and', 'CC'),
#  ('keeping', 'VBG'),
#  ('The', 'DT'),
#  ('catastrophe', 'NN'),
#  ('of', 'IN'),
#  ('Mansfield', 'NNP'),
#  ('Park', 'NNP'),
#  ('is', 'VBZ'),
#  ('admittedly', 'RB'),
#  ('theatrical', 'JJ'),
#  ('the', 'DT'),
#  ('hero', 'NN'),
#  ('and', 'CC'),
#  ('heroine', 'NN'),
#  ('are', 'VBP'),
#  ('insipid', 'JJ'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('author', 'NN'),
#  ('has', 'VBZ'),
#  ('almost', 'RB'),
#  ('wickedly', 'RB'),
#  ('destroyed', 'JJ'),
#  ('all', 'DT'),
#  ('romantic', 'JJ'),
#  ('interest', 'NN'),
#  ('by', 'IN'),
#  ('expressly', 'RB'),
#  ('admitting', 'VBG'),
#  ('that', 'IN'),
#  ('Edmund', 'NNP'),
#  ('only', 'RB'),
#  ('took', 'VBD'),
#  ('Fanny', 'NNP'),
#  ('because', 'IN'),
#  ('Mary', 'NNP'),
#  ('shocked', 'VBD'),
#  ('him', 'PRP'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('Fanny', 'NNP'),
#  ('might', 'MD'),
#  ('very', 'RB'),
#  ('likely', 'RB'),
#  ('have', 'VBP'),
#  ('taken', 'VBN'),
#  ('Crawford', 'NNP'),
#  ('if', 'IN'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('little', 'RB'),
#  ('more', 'RBR'),
#  ('assiduous', 'JJ'),
#  ('yet', 'RB'),
#  ('the', 'DT'),
#  ('matchless', 'NN'),
#  ('rehearsalscenes', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('characters', 'NNS'),
#  ('of', 'IN'),
#  ('Mrs', 'NNP'),
#  ('Norris', 'NNP'),
#  ('and', 'CC'),
#  ('others', 'NNS'),
#  ('have', 'VBP'),
#  ('secured', 'VBN'),
#  ('I', 'PRP'),
#  ('believe', 'VBP'),
#  ('a', 'DT'),
#  ('considerable', 'JJ'),
#  ('party', 'NN'),
#  ('for', 'IN'),
#  ('it', 'PRP'),
#  ('Sense', 'NNP'),
#  ('and', 'CC'),
#  ('Sensibility', 'NNP'),
#  ('has', 'VBZ'),
#  ('perhaps', 'RB'),
#  ('the', 'DT'),
#  ('fewest', 'JJS'),
#  ('outandout', 'NN'),
#  ('admirers', 'NNS'),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('want', 'VB'),
#  ('them', 'PRP'),
#  ('I', 'PRP'),
#  ('suppose', 'VBP'),
#  ('however', 'RB'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('majority', 'NN'),
#  ('of', 'IN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('competent', 'JJ'),
#  ('votes', 'NNS'),
#  ('would', 'MD'),
#  ('all', 'DT'),
#  ('things', 'NNS'),
#  ('considered', 'VBN'),
#  ('be', 'VB'),
#  ('divided', 'VBN'),
#  ('between', 'IN'),
#  ('Emma', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('present', 'JJ'),
#  ('book', 'NN'),
#  ('and', 'CC'),
#  ('perhaps', 'RB'),
#  ('the', 'DT'),
#  ('vulgar', 'NN'),
#  ('verdict', 'NN'),
#  ('if', 'IN'),
#  ('indeed', 'RB'),
#  ('a', 'DT'),
#  ('fondness', 'NN'),
#  ('for', 'IN'),
#  ('Miss', 'NNP'),
#  ('Austen', 'NNP'),
#  ('be', 'VB'),
#  ('not', 'RB'),
#  ('of', 'IN'),
#  ('itself', 'PRP'),
#  ('a', 'DT'),
#  ('patent', 'NN'),
#  ('of', 'IN'),
#  ('exemption', 'NN'),
#  ('from', 'IN'),
#  ('any', 'DT'),
#  ('possible', 'JJ'),
#  ('charge', 'NN'),
#  ('of', 'IN'),
#  ('vulgarity', 'NN'),
#  ('would', 'MD'),
#  ('go', 'VB'),
#  ('for', 'IN'),
#  ('Emma', 'NNP'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('larger', 'JJR'),
#  ('the', 'DT'),
#  ('more', 'RBR'),
#  ('varied', 'VBD'),
#  ('the', 'DT'),
#  ('more', 'RBR'),
#  ('popular', 'JJ'),
#  ('the', 'DT'),
#  ('author', 'NN'),
#  ('had', 'VBD'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('composition', 'NN'),
#  ('seen', 'VBN'),
#  ('rather', 'RB'),
#  ('more', 'JJR'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('and', 'CC'),
#  ('had', 'VBD'),
#  ('improved', 'VBN'),
#  ('her', 'PRP$'),
#  ('general', 'JJ'),
#  ('though', 'IN'),
#  ('not', 'RB'),
#  ('her', 'PRP$'),
#  ('most', 'RBS'),
#  ('peculiar', 'JJ'),
#  ('and', 'CC'),
#  ('characteristic', 'JJ'),
#  ('dialogue', 'NN'),
#  ('such', 'JJ'),
#  ('figures', 'NNS'),
#  ('as', 'IN'),
#  ('Miss', 'NNP'),
#  ('Bates', 'NNP'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Eltons', 'NNS'),
#  ('can', 'MD'),
#  ('not', 'RB'),
#  ('but', 'CC'),
#  ('unite', 'VBP'),
#  ('the', 'DT'),
#  ('suffrages', 'NNS'),
#  ('of', 'IN'),
#  ('everybody', 'NN'),
#  ('On', 'IN'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('hand', 'NN'),
#  ('I', 'PRP'),
#  ('for', 'IN'),
#  ('my', 'PRP$'),
#  ('part', 'NN'),
#  ('declare', 'NN'),
#  ('for', 'IN'),
#  ('Pride', 'NNP'),
#  ('and', 'CC'),
#  ('Prejudice', 'NNP'),
#  ('unhesitatingly', 'RB'),
#  ('It', 'PRP'),
#  ('seems', 'VBZ'),
#  ('to', 'TO'),
#  ('me', 'PRP'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('perfect', 'VBP'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('characteristic', 'JJ'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('eminently', 'RB'),
#  ('quintessential', 'JJ'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('authors', 'NNS'),
#  ('works', 'NNS'),
#  ('and', 'CC'),
#  ('for', 'IN'),
#  ('this', 'DT'),
#  ('contention', 'NN'),
#  ('in', 'IN'),
#  ('such', 'JJ'),
#  ('narrow', 'JJ'),
#  ('space', 'NN'),
#  ('as', 'IN'),
#  ('is', 'VBZ'),
#  ('permitted', 'VBN'),
#  ('to', 'TO'),
#  ('me', 'PRP'),
#  ('I', 'PRP'),
#  ('propose', 'VBP'),
#  ('here', 'RB'),
#  ('to', 'TO'),
#  ('show', 'VB'),
#  ('cause', 'NN'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('place', 'NN'),
#  ('the', 'DT'),
#  ('book', 'NN'),
#  ('it', 'PRP'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('barely', 'RB'),
#  ('necessary', 'JJ'),
#  ('to', 'TO'),
#  ('remind', 'VB'),
#  ('the', 'DT'),
#  ('reader', 'NN'),
#  ('was', 'VBD'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('first', 'JJ'),
#  ('shape', 'NN'),
#  ('written', 'VBN'),
#  ('very', 'RB'),
#  ('early', 'RB'),
#  ('somewhere', 'RB'),
#  ('about', 'IN'),
#  ('1796', 'CD'),
#  ('when', 'WRB'),
#  ('Miss', 'NNP'),
#  ('Austen', 'NNP'),
#  ('was', 'VBD'),
#  ('barely', 'RB'),
#  ('twentyone', 'JJ'),
#  ('though', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('revised', 'VBN'),
#  ('and', 'CC'),
#  ('finished', 'VBN'),
#  ('at', 'IN'),
#  ('Chawton', 'NNP'),
#  ('some', 'DT'),
#  ('fifteen', 'JJ'),
#  ('years', 'NNS'),
#  ('later', 'RB'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('not', 'RB'),
#  ('published', 'VBN'),
#  ('till', 'NN'),
#  ('1813', 'CD'),
#  ('only', 'RB'),
#  ('four', 'CD'),
#  ('years', 'NNS'),
#  ('before', 'IN'),
#  ('her', 'PRP$'),
#  ('death', 'NN'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('know', 'VB'),
#  ('whether', 'IN'),
#  ('in', 'IN'),
#  ('this', 'DT'),
#  ('combination', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('fresh', 'JJ'),
#  ('and', 'CC'),
#  ('vigorous', 'JJ'),
#  ('projection', 'NN'),
#  ('of', 'IN'),
#  ('youth', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('critical', 'JJ'),
#  ('revision', 'NN'),
#  ('of', 'IN'),
#  ('middle', 'JJ'),
#  ('life', 'NN'),
#  ('there', 'EX'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('traced', 'VBN'),
#  ('the', 'DT'),
#  ('distinct', 'JJ'),
#  ('superiority', 'NN'),
#  ('in', 'IN'),
#  ('point', 'NN'),
#  ('of', 'IN'),
#  ('construction', 'NN'),
#  ('which', 'WDT'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('seems', 'VBZ'),
#  ('to', 'TO'),
#  ('me', 'PRP'),
#  ('it', 'PRP'),
#  ('possesses', 'VBZ'),
#  ('over', 'IN'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('others', 'NNS'),
#  ('The', 'DT'),
#  ('plot', 'NN'),
#  ('though', 'IN'),
#  ('not', 'RB'),
#  ('elaborate', 'JJ'),
#  ('is', 'VBZ'),
#  ('almost', 'RB'),
#  ('regular', 'JJ'),
#  ('enough', 'RB'),
#  ('for', 'IN'),
#  ('Fielding', 'VBG'),
#  ('hardly', 'RB'),
#  ('a', 'DT'),
#  ('character', 'NN'),
#  ('hardly', 'RB'),
#  ('an', 'DT'),
#  ('incident', 'NN'),
#  ('could', 'MD'),
#  ('be', 'VB'),
#  ('retrenched', 'VBN'),
#  ('without', 'IN'),
#  ('loss', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('story', 'NN'),
#  ('The', 'DT'),
#  ('elopement', 'NN'),
#  ('of', 'IN'),
#  ('Lydia', 'NNP'),
#  ('and', 'CC'),
#  ('Wickham', 'NNP'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('like', 'IN'),
#  ('that', 'DT'),
#  ('of', 'IN'),
#  ('Crawford', 'NNP'),
#  ('and', 'CC'),
#  ('Mrs', 'NNP'),
#  ('Rushworth', 'NNP'),
#  ('a', 'DT'),
#  ('coup', 'NN'),
#  ('de', 'IN'),
#  ('thtre', 'FW'),
#  ('it', 'PRP'),
#  ('connects', 'VBZ'),
#  ('itself', 'PRP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('strictest', 'JJS'),
#  ('way', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('course', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('story', 'NN'),
#  ('earlier', 'RBR'),
#  ('and', 'CC'),
#  ('brings', 'VBZ'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('denouement', 'NN'),
#  ('with', 'IN'),
#  ('complete', 'JJ'),
#  ('propriety', 'NN'),
#  ('All', 'PDT'),
#  ('the', 'DT'),
#  ('minor', 'JJ'),
#  ('passagesthe', 'NN'),
#  ('loves', 'NNS'),
#  ('of', 'IN'),
#  ('Jane', 'NNP'),
#  ('and', 'CC'),
#  ('Bingley', 'NNP'),
#  ('the', 'DT'),
#  ('advent', 'NN'),
#  ('of', 'IN'),
#  ('Mr', 'NNP'),
#  ('Collins', 'NNP'),
#  ('the', 'DT'),
#  ('visit', 'NN'),
#  ('to', 'TO'),
#  ('Hunsford', 'NNP'),
#  ('the', 'DT'),
#  ('Derbyshire', 'NNP'),
#  ('tourfit', 'NN'),
#  ('in', 'IN'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('unostentatious', 'JJ'),
#  ('but', 'CC'),
#  ('masterly', 'JJ'),
#  ('fashion', 'NN'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('no', 'DT'),
#  ('attempt', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('hideandseek', 'NN'),
#  ('inandout', 'NN'),
#  ('business', 'NN'),
#  ('which', 'WDT'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('transactions', 'NNS'),
#  ('between', 'IN'),
#  ('Frank', 'NNP'),
#  ('Churchill', 'NNP'),
#  ('and', 'CC'),
#  ('Jane', 'NNP'),
#  ('Fairfax', 'NNP'),
#  ('contributes', 'VBZ'),
#  ('no', 'DT'),
#  ('doubt', 'NN'),
#  ('a', 'DT'),
#  ('good', 'JJ'),
#  ('deal', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('intrigue', 'NN'),
#  ('of', 'IN'),
#  ('Emma', 'NNP'),
#  ('but', 'CC'),
#  ('contributes', 'VBZ'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('fashion', 'NN'),
#  ('which', 'WDT'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('think', 'VB'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('feature', 'NN'),
#  ('of', 'IN'),
#  ('that', 'DT'),
#  ('otherwise', 'RB'),
#  ('admirable', 'JJ'),
#  ('book', 'NN'),
#  ('Although', 'IN'),
#  ('Miss', 'NNP'),
#  ('Austen', 'NNP'),
#  ('always', 'RB'),
#  ('liked', 'VBD'),
#  ('something', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('misunderstanding', 'NN'),
#  ('kind', 'NN'),
#  ('which', 'WDT'),
#  ('afforded', 'VBD'),
#  ('her', 'PRP$'),
#  ('opportunities', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('display', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('peculiar', 'NN'),
#  ('and', 'CC'),
#  ('incomparable', 'JJ'),
#  ('talent', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('noticed', 'VBN'),
#  ('presently', 'RB'),
#  ('she', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('satisfied', 'VBN'),
#  ('here', 'RB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('perfectly', 'RB'),
#  ('natural', 'JJ'),
#  ('occasions', 'NNS'),
#  ('provided', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('false', 'JJ'),
#  ('account', 'NN'),
#  ('of', 'IN'),
#  ('Darcys', 'NNP'),
#  ('conduct', 'NN'),
#  ('given', 'VBN'),
#  ('by', 'IN'),
#  ('Wickham', 'NNP'),
#  ('and', 'CC'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('awkwardness', 'NN'),
#  ('arising', 'VBG'),
#  ('with', 'IN'),
#  ('equal', 'JJ'),
#  ('naturalness', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('gradual', 'JJ'),
#  ('transformation', 'NN'),
#  ('of', 'IN'),
#  ('Elizabeths', 'NNP'),
#  ('own', 'JJ'),
#  ('feelings', 'NNS'),
#  ('from', 'IN'),
#  ('positive', 'JJ'),
#  ('aversion', 'NN'),
#  ('to', 'TO'),
#  ('actual', 'JJ'),
#  ('love', 'NN'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('know', 'VB'),
#  ('whether', 'IN'),
#  ('the', 'DT'),
#  ('allgrasping', 'VBG'),
#  ('hand', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('playwright', 'NN'),
#  ('has', 'VBZ'),
#  ('ever', 'RB'),
#  ('been', 'VBN'),
#  ('laid', 'VBN'),
#  ('upon', 'IN'),
#  ('Pride', 'NNP'),
#  ...]

# %%
# Convert PoS tags to a DataFrame
pride_prejudice_df = pd.DataFrame(pos_tags, columns=['Word', 'PoS'])
pride_prejudice_df
# Out:
#              Word  PoS
# 0             The   DT
# 1         Project  NNP
# 2       Gutenberg  NNP
# 3           eBook   NN
# 4              of   IN
# ...           ...  ...
# 130455         to   TO
# 130456       hear   VB
# 130457      about   IN
# 130458        new   JJ
# 130459     eBooks  NNS
#
# [130460 rows x 2 columns]

# %% [markdown]
# ### Data frames and plotting
# Let's see what the most common 10 nouns in the book are and familiarize ourselves with the use of plots for data visualization.

# %%
import matplotlib.pyplot as plt

noun_df = pride_prejudice_df[pride_prejudice_df['PoS'].isin(['NN', 'NNP'])]  # filter to keep only singular nouns
noun_counts = noun_df['Word'].value_counts().head(10)  # count noun occurrences
noun_counts
# Out:
# Mr           805
# Elizabeth    596
# Darcy        378
# Mrs          355
# Miss         306
# Bennet       306
# Jane         270
# Bingley      260
# time         200
# nothing      169
# Name: Word, dtype: int64

# %%
# We'll first plot using the built in pandas plot functionality (still requires the plt dependency for it to work)
noun_counts.plot(kind='bar')  # plot the results
plt.show()

# %%
# It feels a bit more natural to visualize the values on the X axis, so we'll slightly tweak the plot parameters
noun_counts_ascending = noun_counts.sort_values(ascending=True) # We sort the values in ascending order first, feels more natural to see the lowest values at the bottom, highest at the top
noun_counts_ascending.plot(kind='barh')  # We use barh instead of bar to switch to horizontal view
plt.show()

# %% [markdown]
# Let's switch to a slightly prettier visualization library

# %%
import seaborn as sns

noun_counts_descending = noun_counts.sort_values(ascending=False) # Seaborn plots by default in the opposite order of matplotlib, so for this case we sort the data descending

plt.figure(figsize=(10, 6))
sns.barplot(y=noun_counts_descending.index, x=noun_counts_descending.values, orient='h', color='b', palette='GnBu_r')
plt.title('Top 10 Most Common Nouns')
plt.xlabel('Frequency')
plt.ylabel('Noun')
plt.show()

# %% [markdown]
# And let's draw a more serious plot, one showing the most common 10 nouns, verbs, adjectives and pronouns

# %%
# Count occurrences of each PoS
# We first filter based on PoS, then count the occurrences and keep the top 10
noun_counts = pride_prejudice_df.loc[pride_prejudice_df['PoS'].str.startswith('N'), 'Word'].value_counts().head(10) # all the noun pos tags start with N
verb_counts = pride_prejudice_df.loc[pride_prejudice_df['PoS'].str.startswith('V'), 'Word'].value_counts().head(10)
adj_counts = pride_prejudice_df.loc[pride_prejudice_df['PoS'].str.startswith('JJ'), 'Word'].value_counts().head(10)
pronoun_counts = pride_prejudice_df.loc[pride_prejudice_df['PoS'].str.startswith('PR'), 'Word'].value_counts().head(10)

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8)) # Our figure will be comprised of 2 x 2 subplots
sns.barplot(x=noun_counts, y=noun_counts.index, ax=axes[0, 0], palette='Blues_r') # The x axis will depict the count, the y axis will depict the noun (which is the df index), the palette specifies a blue gradient
sns.barplot(x=verb_counts, y=verb_counts.index, ax=axes[0, 1], palette='Greens_r')
sns.barplot(x=adj_counts, y=adj_counts.index, ax=axes[1, 0], palette='Reds_r')
sns.barplot(x=pronoun_counts, y=pronoun_counts.index, ax=axes[1, 1], palette='Oranges_r')

# Set plot titles
axes[0, 0].set_title('Most Common Nouns')
axes[0, 1].set_title('Most Common Verbs')
axes[1, 0].set_title('Most Common Adjectives')
axes[1, 1].set_title('Most Common Pronouns')

# Set y-axis labels to be more readable
for ax in axes.flat:
    ax.set_ylabel('')

# Set overall plot title and adjust spacing
plt.suptitle('Frequency of Most Common Words by Part of Speech', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ### Exercise 1
#
# 1. Create a dataframe containing the word and PoS tag columns out of two books. You can choose any book you like, but one of them has to be on a scientific (physics, biology, history, geography, etc.) topic, and the other one needs to be a story/novel.
#
# 2. Find the most common 10 nouns of each book.
#
# 3. Draw the most common 10 nouns of each book inside the same plot.
#
# 4. Draw a plot showing the most common 10 nouns, verbs, adjectives and adverbs from one of the two books (you can choose whichever).

# %%
# Ex 1.1

# Opticks, by Isaac Newton
book_url = 'https://www.gutenberg.org/cache/epub/33504/pg33504.txt'
response = requests.get(book_url)
newton = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
newton = ''.join(c for c in newton if c in allowed_chars)

# A Journey to the Centre of the Earth, by Jules Verne
book_url = 'https://www.gutenberg.org/cache/epub/18857/pg18857.txt'
response = requests.get(book_url)
verne = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
verne = ''.join(c for c in verne if c in allowed_chars)

# %%
newton_tokens = nltk.word_tokenize(newton)
verne_tokens  = nltk.word_tokenize(verne)

newton_pos_tags = nltk.pos_tag(newton_tokens)
verne_pos_tags  = nltk.pos_tag( verne_tokens)

newton_df = pd.DataFrame(newton_pos_tags, columns=['Word', 'PoS'])
verne_df  = pd.DataFrame(verne_pos_tags, columns=['Word', 'PoS'])

newton_df['Author'] = 'Isaac Newton'
verne_df['Author']  = 'Jules Verne'

# %%
books_df = pd.concat([newton_df, verne_df], axis=0)
books_df
# Out:
#             Word  PoS        Author
# 0            The   DT  Isaac Newton
# 1        Project  NNP  Isaac Newton
# 2      Gutenberg  NNP  Isaac Newton
# 3          EBook  NNP  Isaac Newton
# 4             of   IN  Isaac Newton
# ...          ...  ...           ...
# 88806         to   TO   Jules Verne
# 88807       hear   VB   Jules Verne
# 88808      about   IN   Jules Verne
# 88809        new   JJ   Jules Verne
# 88810     eBooks  NNS   Jules Verne
#
# [192113 rows x 3 columns]

# %%
# Ex 1.2 Find the most common 10 nouns of each book.

newton_noun_df = newton_df[newton_df['PoS'].isin(['NN', 'NNP'])]  # filter to keep only singular nouns
newton_noun_counts = newton_noun_df['Word'].value_counts().head(10)  # count noun occurrences
print(newton_noun_counts)
print()

verne_noun_df = verne_df[verne_df['PoS'].isin(['NN', 'NNP'])]  # filter to keep only singular nouns
verne_noun_counts = verne_noun_df['Word'].value_counts().head(10)  # count noun occurrences
print(verne_noun_counts)
print()
# Out:
# Light         798
# Colours       546
# Rays          432
# Prism         318
# Glass         305
# Refraction    296
# Colour        287
# Paper         243
# Water         230
# distance      217
# Name: Word, dtype: int64
#
# uncle        445
# My           178
# Professor    173
# earth        139
# time         126
# water        119
# way          115
# man          103
# day          101
# sea           98
# Name: Word, dtype: int64

# %%
# Ex 1.3 Draw the most common 10 nouns of each book inside the same plot.

fig, ax = plt.subplots()

newton_noun_counts_s = newton_noun_counts.sort_values(ascending=True)
verne_noun_counts_s = verne_noun_counts.sort_values(ascending=True)

ax.barh(newton_noun_counts_s.index, newton_noun_counts_s.values, label='Isaac Newton')
ax.barh(verne_noun_counts_s.index, verne_noun_counts_s.values, label='Jules Verne')
ax.set_ylabel('Nouns')
ax.set_xlabel('Number of appearances')
ax.set_title('Most common nouns')
ax.legend()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4)) # Our figure will be comprised of 2 x 1 subplots
sns.barplot(x=newton_noun_counts, y=newton_noun_counts.index, ax=axes[0], palette='Blues_r') # The x axis will depict the count, the y axis will depict the noun (which is the df index), the palette specifies a blue gradient
sns.barplot(x=verne_noun_counts, y=verne_noun_counts.index, ax=axes[1], palette='Greens_r')

axes[0].set_title('Isaac Newton')
axes[1].set_title('Jules Verne')
\
for ax in axes.flat:
    ax.set_ylabel('Word')
    ax.set_xlabel('Appearances')

# Set overall plot title and adjust spacing
plt.suptitle('Most common nouns', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Ex 1.4 Draw a plot showing the most common 10 nouns, verbs, adjectives and adverbs from one of the two books (you can choose whichever).

# Count occurrences of each PoS
# We first filter based on PoS, then count the occurrences and keep the top 10
verne_noun_counts = verne_df.loc[verne_df['PoS'].str.startswith('N'),  'Word'].value_counts().head(10) # all the noun pos tags start with N
verne_verb_counts = verne_df.loc[verne_df['PoS'].str.startswith('V'),  'Word'].value_counts().head(10)
verne_adjc_counts = verne_df.loc[verne_df['PoS'].str.startswith('JJ'), 'Word'].value_counts().head(10)
verne_advb_counts = verne_df.loc[verne_df['PoS'].str.startswith('RB'), 'Word'].value_counts().head(10)

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8)) # Our figure will be comprised of 2 x 2 subplots
sns.barplot(x=verne_noun_counts, y=verne_noun_counts.index, ax=axes[0, 0], palette='Blues_r'  ) # The x axis will depict the count, the y axis will depict the noun (which is the df index), the palette specifies a blue gradient
sns.barplot(x=verne_verb_counts, y=verne_verb_counts.index, ax=axes[0, 1], palette='Greens_r' )
sns.barplot(x=verne_adjc_counts, y=verne_adjc_counts.index, ax=axes[1, 0], palette='Reds_r'   )
sns.barplot(x=verne_advb_counts, y=verne_advb_counts.index, ax=axes[1, 1], palette='Oranges_r')

# Set plot titles
axes[0, 0].set_title('Most Common Nouns')
axes[0, 1].set_title('Most Common Verbs')
axes[1, 0].set_title('Most Common Adjectives')
axes[1, 1].set_title('Most Common Adverbs')

# Set y-axis labels to be more readable
for ax in axes.flat:
    ax.set_ylabel('Word')
    ax.set_xlabel('Appearances')

# Set overall plot title and adjust spacing
plt.suptitle('Frequency of Most Common Words by Part of Speech', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ### Named Entity Recognition
#
# Named Entity Recognition (NER) is a Natural Language Processing (NLP) technique that involves identifying and classifying named entities in text into predefined categories such as person names, organization names, locations, medical codes, etc.
#
# The main goal of NER is to extract relevant information about entities from text documents and provide structured information that can be used for various purposes such as information retrieval, question answering, text summarization, sentiment analysis, and more.
#
# Nltk has some built-in NER functionality, but it is slower and relatively old, making it quite far from state of the art. For this reason we are going to use a faster and more power library called **spacy**.
#
# Useful spacy documentation - https://spacy.io/usage/linguistic-features

# %%
#pip install spacy
# Out:
# Requirement already satisfied: spacy in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: setuptools in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (63.4.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (1.1.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (1.10.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: packaging>=20.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: jinja2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from spacy) (8.1.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!python -m spacy download en_core_web_lg # Download the large spacy en_core_web model
# Can replace with en_core_web_sm if you have network/cpu bottlenecks
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy

# Load the pre-trained model
nlp = spacy.load('en_core_web_lg') # Use en_core_web_sm if en_core_web_lg takes too long to download and load, but it will be at the cost of entity recognition accuracy

# %% [markdown]
# ### Take a look at how spacy NER works

# %%
# Define the text to be analyzed
text = "Apple is looking at buying U.K. startup for $1 billion"

# Process the text with spaCy
doc = nlp(text)

# Print each token's text and its predicted named entity label
for token in doc:
    print(token.text, token.ent_type_)
# Out:
# Apple ORG
# is
# looking
# at
# buying
# U.K. GPE
# startup
# for
# $ MONEY
# 1 MONEY
# billion MONEY

# %% [markdown]
# Spacy has its own built-in functionality for displaying named entities in a nice way

# %%
from spacy import displacy

# Generate a visualization of the named entities in the text
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# One simple use case for NER is to automatically redact names. This can prove quite helpful in certain scenarios.
#
# E.g. If you plan to make a large set of documents public and want to comply with GDPR regulations for handling personal data, you may need to remove all the names of individuals mentioned in the documents.

# %% [markdown]
# It's not always necessary to use pandas for our data. Sometimes it could be that processing and manipulating the raw data directly is sufficient.

# %%
# Define the text to be analyzed
before_text = "John Smith is a software engineer at Google."
after_text = before_text[:]

# Process the text with spaCy
doc = nlp(before_text)

# Iterate over each named entity in the document
for ent in doc.ents:
    # If the named entity is a person or an organization that needs to be redacted
    if ent.label_ == 'PERSON':
        after_text = after_text.replace(ent.text, '[REDACTED]')

print(before_text)
print(after_text)
# Out:
# John Smith is a software engineer at Google.
# [REDACTED] is a software engineer at Google.

# %% [markdown]
# SpaCy recognizes the following built-in entity types:
#
#     PERSON - People, including fictional.
#
#     NORP - Nationalities or religious or political groups.
#
#     FAC - Buildings, airports, highways, bridges, etc.
#
#     ORG - Companies, agencies, institutions, etc.
#
#     GPE - Countries, cities, states.
#
#     LOC - Non-GPE locations, mountain ranges, bodies of water.
#
#     PRODUCT - Objects, vehicles, foods, etc. (Not services.)
#
#     EVENT - Named hurricanes, battles, wars, sports events, etc.
#
#     WORK_OF_ART - Titles of books, songs, etc.
#
#     LAW - Named documents made into laws.
#
#     LANGUAGE - Any named language.
#
#     DATE - Absolute or relative dates or periods.
#
#     TIME - Times smaller than a day.
#
#     PERCENT - Percentage, including "%".
#
#     MONEY - Monetary values, including unit.
#
#     QUANTITY - Measurements, as of weight or distance.
#
#     ORDINAL - "first", "second", etc.
#
#     CARDINAL - Numerals that do not fall under another type.

# %% [markdown]
# ### Exercise 2 - Play a game with your colleagues
#
# Find a wikipedia (preferably English) article about a famous person, character, organization or  event of your choice.
#
#
# **Redact all the persons from the page. Redact all the entities of an additional type of your choice besides persons.**
#
#
# Show the final (redacted) text to a colleague and see if they can tell who the wiki page is about.
#
# Below you have an example of how to get a wikipedia article based on id and access its content.

# %%
# We'll use the wikipedia python package to get our page
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from wikipedia) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from wikipedia) (4.11.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: soupsieve>1.2 in /home/andy/Apps/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->wikipedia) (2.3.1)

# %%
import wikipedia

# Fetch the page with the ID "423943"
page = wikipedia.page(pageid='423943') # You can find a page's id by going to the menu in the top left, then going to Page Information

content = page.content
content[:200]
# Out:
# 'The rhesus macaque (Macaca mulatta), colloquially rhesus monkey, is a species of Old World monkey. There are between six and nine recognised subspecies that are split between two groups, the Chinese-d'

# %%
# Ex 2
secret_page = wikipedia.page(pageid='21247')

secret_content = secret_page.content[:232]

# Process the text with spaCy
doc = nlp(secret_content)

# Iterate over each named entity in the document
for ent in doc.ents:
    # If the named entity is a person or an organization that needs to be redacted
    if ent.label_ == 'PERSON':
        secret_content = secret_content.replace(ent.text, '[REDACTED]')
    if ent.label_ == 'NORP':
        secret_content = secret_content.replace(ent.text, '[REDACTED]')
print(secret_content)
# Out:
# [REDACTED] (August 5, 1930 – August 25, 2012) was an [REDACTED] astronaut and aeronautical engineer who became the first person to walk on the Moon in 1969. He was also a naval aviator, test pilot, and university professor.

# %% [markdown]
# ### Spacy tagging
# Once we process a text using spacy, the named entities are not the only information we receive.
#
# We can access a text's named entities using doc.ents() to receive a list of entities, but we also have information stored in each of the doc's tokens.
#
# Some of the most commonly used annotations that are available in the Doc object include:
#
#     Token.text: the original text of the token
#
#     Token.lemma_: the base form of the token
#
#     Token.pos_: the part of speech tag for the token (e.g., "NOUN", "VERB", "ADJ")
#
#     Token.tag_: the detailed part of speech tag for the token (e.g., "NN", "VBD", "JJ")
#
#     Token.dep_: the syntactic dependency label for the token (e.g., "nsubj", "dobj", "pobj")
#
#     Token.is_stop: a boolean indicating whether the token is a stop word or not

# %% [markdown]
# Spacy's dependency parsing can be used to extract specific information from a text, such as the subject and object of a sentence or the relationship between two entities. This information can be used to extract structured data from unstructured text, which can be useful for tasks such as question answering, knowledge graph construction, and more.
#
# Let's look at an example of the dependencies from a sentence.

# %%
# sentence = "The cat sat on the mat."
sentence = "What did Andrei eat?"

doc = nlp(sentence)

for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# What dobj eat
# did aux eat
# Andrei nsubj eat
# eat ROOT eat
# ? punct eat

# %% [markdown]
# Spacy provides functionality for visualizing these dependencies in a more appealing manner using displacy.

# %%
sentence = "What sat on the mat?"

doc = nlp(sentence)

displacy.render(doc, style="dep", options={"compact": True}, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fec7563ad72c46ea892b52b8c23c3a6a-0" class="displacy" width="800" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">sat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">mat?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-0" stroke-width="2px" d="M62,152.0 62,127.0 197.0,127.0 197.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-1" stroke-width="2px" d="M212,152.0 212,127.0 347.0,127.0 347.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,154.0 L351.0,146.0 343.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-2" stroke-width="2px" d="M512,152.0 512,127.0 647.0,127.0 647.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,154.0 L508,146.0 516,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-3" stroke-width="2px" d="M362,152.0 362,102.0 650.0,102.0 650.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fec7563ad72c46ea892b52b8c23c3a6a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,154.0 L654.0,146.0 646.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Question asking
#
# We'll get creative and try to write some code that can automatically transform sentences into questions.
#
# We're gonna write a naive function using scipy functionality.

# %%
def generate_question(sentence):
    # process the input sentence
    doc = nlp(sentence)
    # extract the subject, verb, and object of the sentence
    subject = None
    verb = None
    obj = None
    for token in doc:
        if token.dep_ == "nsubj":
            subject = token.text
        elif token.dep_ == "ROOT":
            verb = token.lemma_ # We want the basis of the word, the lemma - "what did he <eat>?" not "what did he <ate>?"
        elif token.dep_ == "dobj":
            obj = token.text

    # generate a question based on the extracted information
    if subject is not None and verb is not None:
        if obj is not None:
            question = f"What did {subject} {verb}?"
        else:
            question = f"What {verb} {subject} do?"
        return question
    else:
        print("No subject or verb found")
        return None

# example usage
input_sentence = "Michael sent her flowers"
question = generate_question(input_sentence)
print("Generated question:", question)
# Out:
# Generated question: What did Michael send?

# %% [markdown]
# ### Exercise 3 Q & A
#
#
# 1. Create a model that is able to answer simple "Who [verb]?" questions.
#
#     For this, write a function that takes as input a context string and a question string and returns the answer to the question or a message error as output.
#
#         e.g. context - "I can't sleep. Rex barks loudly. He is scared."
#         question - "Who barks?"
#         output - "Rex" or "Rex"
#
#         question - "Who is scared?"
#         output - "He"
#
# 2. Write a sentence of your own, generate the question for it using generate_question() and then answer it using your find_answer() function and the context of your initial sentence.

# %%
# Ex 3.1

def find_answer(context, question):
    
    c_doc = nlp(context)
    c_subject = []
    c_verb    = []
    c_obj     = []
    for token in c_doc:
        if   token.dep_ == "nsubj":
            c_subject.append(token.text)
        elif token.dep_ == "ROOT":
            c_verb.append(token.lemma_)
        elif token.dep_ == "dobj":
            c_obj.append(token.text)
    
    q_doc = nlp(question)
    q_subject = None
    q_verb    = None
    q_obj     = None
    for token in q_doc:
        if   token.dep_ == "nsubj":
            q_subject = token.text
        elif token.dep_ == "ROOT":
            q_verb    = token.lemma_
        elif token.dep_ == "dobj":
            q_obj     = token.text
    
    i=-1
    correct_i=-1
    for verb in c_verb:
        i=i+1
        if q_verb==verb:
            correct_i=i
            break
            
    if correct_i == -1:
        return "I don't know"
    
    for token in q_doc:
        if token.text == "Who":
            if c_subject:
                return c_subject[correct_i]
            else:
                return "I don't know"
        if token.text == "What":
            if c_obj:
                return c_obj[correct_i]
            else:
                return "I don't know"
            
        return "I don't know"
    
    
print(find_answer("I can't sleep. Rex barks loudly. He is scared.", "Who can't sleep?"    ))
print(find_answer("I can't sleep. Rex barks loudly. He is scared.", "Who barks?"          ))
print(find_answer("I can't sleep. Rex barks loudly. He is scared.", "Who is scared?"      ))
print(find_answer("Rex eats dogfood",                               "What does Rex eat?"  ))
# Out:
# I
# Rex
# He
# dogfood

# %%
# Ex 3.2

test_sentence = "Andrei is eating a sandwich."
test_question = generate_question(test_sentence)
print(test_question)
test_answer = find_answer(test_sentence, test_question)
print(test_answer)
# Out:
# What did Andrei eat?
# sandwich

# %% [markdown]
# ### Exercise 4 - Fake News Generator
#
# Somewhat similarly to exercise 2, next up you will be creating a naive fake news generator.
#
# 1. Create a function that takes as input a text, **replaces all the person names with a randomly selected name coming from an input list of names** and then returns the modified text.
#
#     (E.g. can give input_list = ['Barack Obama', 'Donald Trump', 'Bill Gates'] or can also give a list with one element, case in which that's what will always be picked by the random function)
# 2. Create a function that takes as input a text, **replaces all the dates with other randomly generated dates** and then returns the modified text.
#
# 3. **Apply both of these functions (in sequence)** on a news article of your choice from the brown corpus of text.

# %%
import nltk
nltk.download('brown')
from nltk.corpus import brown

# Helper function to join words from brown corpus
def join_words(words):
    text = ''
    for word in words:
        if word in {'.', ',', ';', ':', '?', '!', '(', ')', '``', "''", '--'}:
            text = text.rstrip() + word + ' '
        else:
            text += word + ' '
    return text.strip()

# List of categories in the Brown Corpus
print("Categories", brown.categories())
print()

# Accessing tokenized words
govt_documents = brown.fileids(categories='news')
words = brown.words(govt_documents[5])

# Joining words to form a text
article = join_words(words)
print("Text: ", article)
# Out:
# Categories ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
#
# Text:  Plainfield-- James P. Mitchell and Sen. Walter H. Jones R-Bergen, last night disagreed on the value of using as a campaign issue a remark by Richard J. Hughes, Democratic gubernatorial candidate, that the GOP is`` Campaigning on the carcass of Eisenhower Republicanism''. Mitchell was for using it, Jones against, and Sen. Wayne Dumont Jr. R-Warren did not mention it when the three Republican gubernatorial candidates spoke at staggered intervals before 100 persons at the Park Hotel. The controversial remark was first made Sunday by Hughes at a Westfield Young Democratic Club cocktail party at the Scotch Plains Country Club. It was greeted with a chorus of boos by 500 women in Trenton Monday at a forum of the State Federation of Women's Clubs. Hughes said Monday,`` It is the apparent intention of the Republican Party to campaign on the carcass of what they call Eisenhower Republicanism, but the heart stopped beating and the lifeblood congealed after Eisenhower retired. Now he's gone, the Republican Party is not going to be able to sell the tattered remains to the people of the state''. Sunday he had added,`` We can love Eisenhower the man, even if we considered him a mediocre president but there is nothing left of the Republican Party without his leadership''. Mitchell said the statement should become a major issue in the primary and the fall campaign.`` How can a man with any degree of common decency charge this''?? He asked. The former secretary of labor said he was proud to be an Eisenhower Republican`` and proud to have absorbed his philosophy'' while working in his adminstration. Mitchell said the closeness of the outcome in last fall's Presidential election did not mean that Eisenhower Republicanism was a dead issue. Regrets attack Jones said he regretted Hughes had made a personal attack on a past president.`` He is wrong to inject Eisenhower into this campaign'', he said,`` because the primary is being waged on state issues and I will not be forced into re-arguing an old national campaign''. The audience last night did not respond with either applause or boos to mention of Hughes' remark. Dumont spoke on the merit of having an open primary. He then launched into what the issues should be in the campaign. State aid to schools, the continuance of railroad passenger service, the proper uses of surplus funds of the Port of New York Authority, and making New Jersey attractive to new industry. Decries joblessness Mitchell decried the high rate of unemployment in the state and said the Meyner administration and the Republican-controlled State Senate`` Must share the blame for this''. Noting that Plainfield last year had lost the Mack Truck Co. plant, he said industry will not come into this state until there is tax reform.`` But I am not in favor of a sales or state income tax at this time'', Mitchell said. Jones, unhappy that the candidates were limited to eight minutes for a speech and no audience questions, saved his barbs for Mitchell. He said Mitchell is against the centralization of government in Washington but looks to the Kennedy Administration for aid to meet New Jersey school and transportation crises.`` He calls for help while saying he is against centralization, but you can't have it both ways'', Jones said. The state is now faced with the immediate question of raising new taxes whether on utilities, real estate or motor vehicles, he said,`` and I challenge Mitchell to tell the people where he stands on the tax issue''. Defends Ike Earlier, Mitchell said in a statement:`` I think that all Americans will resent deeply the statements made about President Eisenhower by Richard J. Hughes. His reference to ' discredited carcass ' or ' tattered remains ' of the president's leadership is an insult to the man who led our forces to victory in the greatest war in all history, to the man who was twice elected overwhelmingly by the American people as president of the United States, and who has been the symbol to the world ...
# [nltk_data] Downloading package brown to /home/andy/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
# Ex 4.1
import random

def replace_names (text):
    names = ['Barack Obama', 'Donald Trump', 'Bill Gates']
    doc = nlp(text)

    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            text = text.replace(ent.text, random.choice(names))
    
    return text

# %%
# Ex 4.2

def random_date():
    year  = str( random.randint(1900, 2024) )
    month =      random.randint(   1,   12)
    day   =      random.randint(   1,   30)
    
    if month < 10:
        month = "0" + str(month)
    else:
        month = str(month)
    
    if day < 10:
        day = "0" + str(day)
    else:
        day = str(day)
        
    return day+"/"+month+"/"+year

def replace_dates (text):  
    doc = nlp(text)

    for ent in doc.ents:
        if ent.label_ == 'DATE':
            text = text.replace(ent.text, random_date())
    
    return text
            
print(random_date())
# Out:
# 26/03/2018

# %%
# Ex 4.3

print("Text: ", replace_dates(replace_names(article)))
# Out:
#
# 5. Draw a pie or bar chart to help visualize the above distribution.

# %%
# Ex 5.1

import requests
import string
import pandas as pd

# A Tale of Two Cities, by Charles Dickens
book_url = 'https://www.gutenberg.org/files/98/98-0.txt'
response = requests.get(book_url)
book1 = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
book1 = ''.join(c for c in book1 if c in allowed_chars)

# Alice’s Adventures in Wonderland, by Lewis Carroll
book_url = 'https://www.gutenberg.org/cache/epub/11/pg11.txt'
response = requests.get(book_url)
book2 = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
book2 = ''.join(c for c in book2 if c in allowed_chars)

# The Great Gatsby, by F. Scott Fitzgerald
book_url = 'https://www.gutenberg.org/cache/epub/64317/pg64317.txt'
response = requests.get(book_url)
book3 = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
book3 = ''.join(c for c in book3 if c in allowed_chars)

# War and Peace, by Leo Tolstoy
book_url = 'https://www.gutenberg.org/cache/epub/2600/pg2600.txt'
response = requests.get(book_url)
book4 = response.text
allowed_chars = string.ascii_letters + string.digits + string.whitespace
book4 = ''.join(c for c in book4 if c in allowed_chars)

# %%
# not working

doc = nlp(book1)
book1_df = pd.DataFrame(columns = ['Word', 'Book', 'NER', 'PoS'])
i=0
for token in doc:
    if(token.text.isalnum()):
        i=i+1
        book1_df.loc[i] = [token.text, 'A Tale of Two Cities, by Charles Dickens', token.ent_type_, token.pos_]

doc = nlp(book2)
book2_df = pd.DataFrame(columns = ['Word', 'Book', 'NER', 'PoS'])
i=0
for token in doc:
    if(token.text.isalnum()):
        i=i+1
        book2_df.loc[i] = [token.text, 'Alice’s Adventures in Wonderland, by Lewis Carroll', token.ent_type_, token.pos_]
            
doc = nlp(book3)
book3_df = pd.DataFrame(columns = ['Word', 'Book', 'NER', 'PoS'])
i=0
for token in doc:
    if(token.text.isalnum()):
        i=i+1
        book3_df.loc[i] = [token.text, 'The Great Gatsby, by F. Scott Fitzgerald', token.ent_type_, token.pos_]
        
doc = nlp(book4)
book4_df = pd.DataFrame(columns = ['Word', 'Book', 'NER', 'PoS'])
i=0
for token in doc:
    if(token.text.isalnum()):
        i=i+1
        book4_df.loc[i] = [token.text, 'War and Peace, by Leo Tolstoy', token.ent_type_, token.pos_]
        
books_df = pd.concat([book1_df, book2_df, book3_df, book4_df])
books_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10423/3484812980.py in <module>
#      31             break
#      32
# ---> 33 doc = nlp(book4)
#      34 book4_df = pd.DataFrame(columns = ['Word', 'Book', 'NER', 'PoS'])
#      35 i=0
#
# ~/Apps/anaconda3/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     997         DOCS: https://spacy.io/api/language#call
#     998         """
# --> 999         doc = self._ensure_doc(text)
#    1000         if component_cfg is None:
#    1001             component_cfg = {}
#
# ~/Apps/anaconda3/lib/python3.9/site-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1088             return doc_like
#    1089         if isinstance(doc_like, str):
# -> 1090             return self.make_doc(doc_like)
#    1091         if isinstance(doc_like, bytes):
#    1092             return Doc(self.vocab).from_bytes(doc_like)
#
# ~/Apps/anaconda3/lib/python3.9/site-packages/spacy/language.py in make_doc(self, text)
#    1077         """
#    1078         if len(text) > self.max_length:
# -> 1079             raise ValueError(
#    1080                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1081             )
#
# ValueError: [E088] Text of length 3171779 exceeds maximum of 1000000. The parser and NER models require roughly 1GB of temporary memory per 100,000 characters in the input. This means long texts may cause memory allocation errors. If you're not using the parser or NER, it's probably safe to increase the `nlp.max_length` limit. The limit is in number of characters, so you can check whether your inputs are too long by checking `len(text)`.

# %%
# works

#Book1
doc = nlp(book1)

words = []
ners  = []
pos   = []

for token in doc:
    words.append(token.text)
    ners.append(token.ent_type_ if token.ent_type_ else '')
    pos.append(token.pos_)

book1_df = pd.DataFrame({'Word': words, 'Book' : 'A Tale of Two Cities, by Charles Dickens', 'NER': ners, 'PoS': pos})

#Book2
doc = nlp(book2)

words = []
ners  = []
pos   = []

for token in doc:
    words.append(token.text)
    ners.append(token.ent_type_ if token.ent_type_ else '')
    pos.append(token.pos_)

book2_df = pd.DataFrame({'Word': words, 'Book' : 'Alice’s Adventures in Wonderland, by Lewis Carroll', 'NER': ners, 'PoS': pos})

#Book3
doc = nlp(book3)

words = []
ners  = []
pos   = []

for token in doc:
    words.append(token.text)
    ners.append(token.ent_type_ if token.ent_type_ else '')
    pos.append(token.pos_)

book3_df = pd.DataFrame({'Word': words, 'Book' : 'The Great Gatsby, by F. Scott Fitzgerald', 'NER': ners, 'PoS': pos})

'''
#Book4
doc = nlp(book4)

words = []
ners  = []
pos   = []

for token in doc:
    words.append(token.text)
    ners.append(token.ent_type_ if token.ent_type_ else '')
    pos.append(token.pos_)

book4_df = pd.DataFrame({'Word': words, 'Book' : 'War and Peace, by Leo Tolstoy', 'NER': ners, 'PoS': pos})
'''

books_df = pd.concat([book1_df, book2_df, book3_df ])#, book4_df])
books_df = books_df.reset_index(drop=True)
books_df
# Out:
#             Word                                      Book NER    PoS
# 0            The  A Tale of Two Cities, by Charles Dickens        DET
# 1        Project  A Tale of Two Cities, by Charles Dickens      PROPN
# 2      Gutenberg  A Tale of Two Cities, by Charles Dickens      PROPN
# 3          eBook  A Tale of Two Cities, by Charles Dickens       NOUN
# 4             of  A Tale of Two Cities, by Charles Dickens        ADP
# ...          ...                                       ...  ..    ...
# 57059       hear  The Great Gatsby, by F. Scott Fitzgerald       VERB
# 57060      about  The Great Gatsby, by F. Scott Fitzgerald        ADP
# 57061        new  The Great Gatsby, by F. Scott Fitzgerald      PROPN
# 57062     eBooks  The Great Gatsby, by F. Scott Fitzgerald      PROPN
# 57063       \r\n  The Great Gatsby, by F. Scott Fitzgerald      SPACE
#
# [241899 rows x 4 columns]

# %%
pd.set_option('display.max_rows', 100000)
books_df.head(1000)
# Out:
#                          Word                                      Book  \
# 0                         The  A Tale of Two Cities, by Charles Dickens
# 1                     Project  A Tale of Two Cities, by Charles Dickens
# 594                        we  A Tale of Two Cities, by Charles Dickens
# 595                      were  A Tale of Two Cities, by Charles Dickens
# 596                       all  A Tale of Two Cities, by Charles Dickens
# 597                     going  A Tale of Two Cities, by Charles Dickens
# 598                    direct  A Tale of Two Cities, by Charles Dickens
# 599                       the  A Tale of Two Cities, by Charles Dickens
# 600                     other  A Tale of Two Cities, by Charles Dickens
# 601                     wayin  A Tale of Two Cities, by Charles Dickens
# 602                      \r\n  A Tale of Two Cities, by Charles Dickens
# 603                     short  A Tale of Two Cities, by Charles Dickens
# 604                       the  A Tale of Two Cities, by Charles Dickens
# 605                    period  A Tale of Two Cities, by Charles Dickens
# 606                       was  A Tale of Two Cities, by Charles Dickens
# 607                        so  A Tale of Two Cities, by Charles Dickens
# 608                       far  A Tale of Two Cities, by Charles Dickens
# 609                      like  A Tale of Two Cities, by Charles Dickens
# 610                       the  A Tale of Two Cities, by Charles Dickens
# 611                   present  A Tale of Two Cities, by Charles Dickens
# 612                    period  A Tale of Two Cities, by Charles Dickens
# 613                      that  A Tale of Two Cities, by Charles Dickens
# 614                      some  A Tale of Two Cities, by Charles Dickens
# 615                        of  A Tale of Two Cities, by Charles Dickens
# 616                       its  A Tale of Two Cities, by Charles Dickens
# 617                      \r\n  A Tale of Two Cities, by Charles Dickens
# 618                  noisiest  A Tale of Two Cities, by Charles Dickens
# 619               authorities  A Tale of Two Cities, by Charles Dickens
# 620                  insisted  A Tale of Two Cities, by Charles Dickens
# 621                        on  A Tale of Two Cities, by Charles Dickens
# 622                       its  A Tale of Two Cities, by Charles Dickens
# 623                     being  A Tale of Two Cities, by Charles Dickens
# 624                  received  A Tale of Two Cities, by Charles Dickens
# 625                       for  A Tale of Two Cities, by Charles Dickens
# 626                      good  A Tale of Two Cities, by Charles Dickens
# 627                        or  A Tale of Two Cities, by Charles Dickens
# 628                       for  A Tale of Two Cities, by Charles Dickens
# 629                      \r\n  A Tale of Two Cities, by Charles Dickens
# 630                      evil  A Tale of Two Cities, by Charles Dickens
# 631                        in  A Tale of Two Cities, by Charles Dickens
# 632                       the  A Tale of Two Cities, by Charles Dickens
# 633               superlative  A Tale of Two Cities, by Charles Dickens
# 634                    degree  A Tale of Two Cities, by Charles Dickens
# 635                        of  A Tale of Two Cities, by Charles Dickens
# 636                comparison  A Tale of Two Cities, by Charles Dickens
# 637                      only  A Tale of Two Cities, by Charles Dickens
# 638                  \r\n\r\n  A Tale of Two Cities, by Charles Dickens
# ...
# 385                VERB
# 386                 ADP
# 387          ORG    DET
# 388          ORG  PROPN
# 389          ORG  PROPN
# 390          ORG  SPACE
# 391          ORG  PROPN
# 392                 DET
# 393               PROPN
# 394               PROPN
# 395                 ADP
# 396                 DET
# 397                NOUN
# 398               SPACE
# 399                NOUN
# 400                PRON
# 401               SPACE
# 402                 ADP
# 403                 ADJ
# 404               SPACE
# 405                NOUN
# 406               PROPN
# 407               SPACE
# 408                 DET
# 409          ORG  PROPN
# 410               SPACE
# 411                NOUN
# 412               PROPN
# 413               SPACE
# 414                 DET
# 415               PROPN
# 416               SPACE
# 417                NOUN
# 418               PROPN
# 419               SPACE
# 420               PROPN
# 421                 ADP
# 422                NOUN
# 423               SPACE
# 424                NOUN
# 425                NOUN
# 426               SPACE
# 427                 DET
# 428               PROPN
# 429               SPACE
# 430                NOUN
# 431               PROPN
# 432               SPACE
# 433               PROPN
# 434               SPACE
# 435                NOUN
# 436               PROPN
# 437               SPACE
# 438                PRON
# 439                NOUN
# 440                 ADP
# 441                 DET
# 442               PROPN
# 443               SPACE
# 444                NOUN
# 445               PROPN
# 446               SPACE
# 447               PROPN
# 448               PROPN
# 449                 ADP
# 450               PROPN
# 451               SPACE
# 452                NOUN
# 453               PROPN
# 454               SPACE
# 455  WORK_OF_ART    DET
# 456  WORK_OF_ART  PROPN
# 457  WORK_OF_ART  PROPN
# 458               SPACE
# 459                NOUN
# 460                NOUN
# 461               SPACE
# 462  WORK_OF_ART    DET
# 463  WORK_OF_ART  PROPN
# 464  WORK_OF_ART    ADP
# 465  WORK_OF_ART    DET
# 466  WORK_OF_ART  PROPN
# 467               SPACE
# 468                NOUN
# 469               PROPN
# 470               SPACE
# 471                NOUN
# 472               SPACE
# 473                NOUN
# 474               PROPN
# 475               SPACE
# 476                NOUN
# 477               SPACE
# 478                NOUN
# 479               PROPN
# 480               SPACE
# 481               PROPN
# 482               SPACE
# 483                NOUN
# 484               PROPN
# 485               SPACE
# 486                 DET
# 487                NOUN
# 488                NOUN
# 489               SPACE
# 490                NOUN
# 491               PROPN
# 492               SPACE
# 493  WORK_OF_ART    DET
# 494  WORK_OF_ART  PROPN
# 495  WORK_OF_ART   VERB
# 496  WORK_OF_ART    ADP
# 497  WORK_OF_ART    ADP
# 498  WORK_OF_ART  PROPN
# 499  WORK_OF_ART  SPACE
# 500  WORK_OF_ART  PROPN
# 501                 DET
# 502               PROPN
# 503                 ADP
# 504               PROPN
# 505               SPACE
# 506                NOUN
# 507                PRON
# 508               SPACE
# 509                 DET
# 510               PROPN
# 511               SPACE
# 512                PRON
# 513                 AUX
# 514                 DET
# 515                 ADJ
# 516                 ADP
# 517                NOUN
# 518                PRON
# 519                 AUX
# 520                 DET
# 521                 ADJ
# 522                 ADP
# 523                NOUN
# 524                PRON
# 525                 AUX
# 526                 DET
# 527                NOUN
# 528                 ADP
# 529               SPACE
# 530                NOUN
# 531                PRON
# 532                 AUX
# 533                 DET
# 534                NOUN
# 535                 ADP
# 536                NOUN
# 537                PRON
# 538                 AUX
# 539                 DET
# 540                NOUN
# 541                 ADP
# 542                NOUN
# 543                PRON
# 544               SPACE
# 545                 AUX
# 546                 DET
# 547                NOUN
# 548                 ADP
# 549                NOUN
# 550                PRON
# 551                 AUX
# 552                 DET
# 553                NOUN
# 554                 ADP
# 555                NOUN
# 556                PRON
# 557                 AUX
# 558         DATE    DET
# 559         DATE  SPACE
# 560         DATE   NOUN
# 561                 ADP
# 562      PRODUCT   NOUN
# 563                PRON
# 564                 AUX
# 565                 DET
# 566                NOUN
# 567                 ADP
# 568                NOUN
# 569                PRON
# 570                 AUX
# 571                 DET
# 572                NOUN
# 573                 ADP
# 574               SPACE
# 575                NOUN
# 576                PRON
# 577                VERB
# 578                PRON
# 579                 ADP
# 580                PRON
# 581                PRON
# 582                VERB
# 583                PRON
# 584                 ADP
# 585                PRON
# 586                PRON
# 587                 AUX
# 588               SPACE
# 589                PRON
# 590                VERB
# 591                 ADJ
# 592                 ADP
# 593               PROPN
# 594                PRON
# 595                 AUX
# 596                 ADV
# 597                VERB
# 598                 ADJ
# 599                 DET
# 600                 ADJ
# 601                NOUN
# 602               SPACE
# 603                 ADJ
# 604                 DET
# 605                NOUN
# 606                 AUX
# 607                 ADV
# 608                 ADV
# 609                 ADP
# 610                 DET
# 611                 ADJ
# 612                NOUN
# 613                PRON
# 614                PRON
# 615                 ADP
# 616                PRON
# 617               SPACE
# 618                 ADJ
# 619                NOUN
# 620                VERB
# 621                 ADP
# 622                PRON
# 623                 AUX
# 624                VERB
# 625                 ADP
# 626                 ADJ
# 627               CCONJ
# 628                 ADP
# 629               SPACE
# 630                NOUN
# 631                 ADP
# 632                 DET
# 633                 ADJ
# 634                NOUN
# 635                 ADP
# 636                NOUN
# 637                 ADV
# 638               SPACE
# 639                PRON
# 640                VERB
# 641                 DET
# 642                NOUN
# 643                 ADP
# 644                 DET
# 645                 ADJ
# 646                NOUN
# 647               CCONJ
# 648                 DET
# 649                NOUN
# 650                 ADP
# 651                 DET
# 652                 ADJ
# 653                NOUN
# 654                 ADP
# 655                 DET
# 656               SPACE
# 657                NOUN
# 658                 ADP
# 659          GPE  PROPN
# 660                PRON
# 661                VERB
# 662                 DET
# 663                NOUN
# 664                 ADP
# 665                 DET
# 666                 ADJ
# 667                NOUN
# 668               CCONJ
# 669                 DET
# 670                NOUN
# 671                 ADP
# 672               SPACE
# 673                 DET
# 674                 ADJ
# 675                NOUN
# 676                 ADP
# 677                 DET
# 678                NOUN
# 679                 ADP
# 680          GPE  PROPN
# 681                 ADP
# 682                 DET
# 683                NOUN
# 684                PRON
# 685                 AUX
# 686                 ADJ
# 687               SPACE
# 688                 ADP
# 689                NOUN
# 690                 ADP
# 691                 DET
# 692                NOUN
# 693                 ADP
# 694                 DET
# 695          ORG  PROPN
# 696                NOUN
# 697                 ADP
# 698                NOUN
# 699               CCONJ
# 700                NOUN
# 701               SPACE
# 702               SCONJ
# 703                NOUN
# 704                 ADP
# 705                 ADJ
# 706                 AUX
# 707                VERB
# 708                 ADP
# 709                 ADV
# 710               SPACE
# 711                PRON
# 712                 AUX
# 713         DATE    DET
# 714         DATE   NOUN
# 715                 ADP
# 716                PRON
# 717               PROPN
# 718                 NUM
# 719                 NUM
# 720                 NUM
# 721                 NUM
# 722               CCONJ
# 723                 ADJ
# 724               SPACE
# 725                 ADJ
# 726                NOUN
# 727                 AUX
# 728                VERB
# 729                 ADP
# 730          GPE  PROPN
# 731                 ADP
# 732                 DET
# 733                 ADJ
# 734                NOUN
# 735               SPACE
# 736               SCONJ
# 737                 ADP
# 738                PRON
# 739               PROPN
# 740       PERSON  PROPN
# 741                 AUX
# 742                 ADV
# 743                VERB
# 744                PRON
# 745                NOUN
# 746               SPACE
# 747                VERB
# 748                NOUN
# 749                 ADP
# 750                PRON
# 751                 DET
# 752                 ADJ
# 753                NOUN
# 754                 ADP
# 755          ORG    DET
# 756          ORG  PROPN
# 757          ORG  PROPN
# 758                 AUX
# 759               SPACE
# 760                VERB
# 761                 DET
# 762                 ADJ
# 763                NOUN
# 764                 ADP
# 765                VERB
# 766               SCONJ
# 767                NOUN
# 768                 AUX
# 769               SPACE
# 770                VERB
# 771                 ADP
# 772                 DET
# 773                NOUN
# 774                 ADP
# 775                 ADP
# 776          GPE  PROPN
# 777               CCONJ
# 778          GPE  PROPN
# 779                 ADV
# 780                 DET
# 781          ORG  PROPN
# 782               SPACE
# 783                NOUN
# 784                 AUX
# 785                 AUX
# 786                VERB
# 787     CARDINAL    ADV
# 788     CARDINAL    DET
# 789     CARDINAL    ADJ
# 790     CARDINAL   NOUN
# 791                 ADP
# 792                NOUN
# 793                 ADP
# 794                VERB
# 795                 ADP
# 796                PRON
# 797               SPACE
# 798                NOUN
# 799                 ADP
# 800                 DET
# 801                NOUN
# 802                 ADP
# 803         DATE    DET
# 804         DATE    ADJ
# 805         DATE   NOUN
# 806         DATE    ADJ
# 807         DATE    ADV
# 808                 ADV
# 809               SPACE
# 810                 ADJ
# 811                 ADP
# 812                NOUN
# 813                VERB
# 814                 ADP
# 815                PRON
# 816               PROPN
# 817                NOUN
# 818                 ADP
# 819                 DET
# 820               SPACE
# 821                 ADJ
# 822                NOUN
# 823                 ADP
# 824                NOUN
# 825                 AUX
# 826                 ADV
# 827                VERB
# 828                 ADP
# 829                 DET
# 830     LANGUAGE  PROPN
# 831      PRODUCT  PROPN
# 832               CCONJ
# 833                NOUN
# 834               SPACE
# 835                 ADP
# 836                 DET
# 837          ORG  PROPN
# 838                 ADP
# 839         NORP    ADJ
# 840                NOUN
# 841                 ADP
# 842          GPE  PROPN
# 843                PRON
# 844                VERB
# 845               SPACE
# 846                PART
# 847                VERB
# 848                 AUX
# 849                VERB
# 850                 ADV
# 851                 ADJ
# 852                 ADP
# 853                 DET
# 854                 ADJ
# 855                NOUN
# 856                 ADP
# 857                 DET
# 858               SPACE
# 859                NOUN
# 860                 ADV
# 861                VERB
# 862                 ADP
# 863                PRON
# 864                 ADP
# 865                 DET
# 866                NOUN
# 867                 ADP
# 868                 DET
# 869          ORG  PROPN
# 870               SPACE
# 871               PROPN
# 872               SPACE
# 873          GPE  PROPN
# 874                 ADV
# 875                VERB
# 876                 ADP
# 877                 DET
# 878                NOUN
# 879                 ADP
# 880                 ADP
# 881                NOUN
# 882                 ADJ
# 883                 ADP
# 884                PRON
# 885               SPACE
# 886                NOUN
# 887                 ADP
# 888                 DET
# 889                NOUN
# 890               CCONJ
# 891                NOUN
# 892                VERB
# 893                 ADP
# 894                VERB
# 895                NOUN
# 896                 ADP
# 897               SPACE
# 898                NOUN
# 899                VERB
# 900                NOUN
# 901                NOUN
# 902               CCONJ
# 903                VERB
# 904                PRON
# 905                 ADP
# 906                 DET
# 907                NOUN
# 908                 ADP
# 909                PRON
# 910               SPACE
# 911         NORP    ADJ
# 912                NOUN
# 913                PRON
# 914                VERB
# 915                PRON
# 916               SCONJ
# 917                 ADP
# 918                 ADJ
# 919                 ADJ
# 920               SPACE
# 921                NOUN
# 922                 ADP
# 923                VERB
# 924                 DET
# 925                NOUN
# 926                PART
# 927                VERB
# 928                PRON
# 929                NOUN
# 930                VERB
# 931                 ADP
# 932                PRON
# 933                NOUN
# 934               SPACE
# 935                VERB
# 936                 ADP
# 937                 ADP
# 938                NOUN
# 939               CCONJ
# 940                PRON
# 941                NOUN
# 942                VERB
# 943                 ADJ
# 944               SCONJ
# 945                PRON
# 946                 AUX
# 947                PART
# 948               SPACE
# 949                VERB
# 950                 ADP
# 951                 ADP
# 952                 DET
# 953                NOUN
# 954                PART
# 955                 AUX
# 956                VERB
# 957                 ADP
# 958                 DET
# 959                 ADJ
# 960                NOUN
# 961                 ADP
# 962                NOUN
# 963               SPACE
# 964                PRON
# 965                VERB
# 966                 ADP
# 967                PRON
# 968                NOUN
# 969                 ADP
# 970                 DET
# 971                NOUN
# 972                 ADP
# 973     CARDINAL    DET
# 974     CARDINAL    NUM
# 975     CARDINAL  CCONJ
# 976     QUANTITY    NUM
# 977     QUANTITY  SPACE
# 978     QUANTITY   NOUN
# 979                PRON
# 980                 AUX
# 981                 ADJ
# 982                 ADV
# 983               SCONJ
# 984                VERB
# 985                 ADP
# 986                 DET
# 987                NOUN
# 988                 ADP
# 989          GPE  PROPN
# 990               CCONJ
# 991               SPACE
# 992          GPE  PROPN
# 993                PRON
# 994                VERB
# 995                VERB
# 996                NOUN
# 997               SCONJ
# 998                 DET
# 999                NOUN

# %%
# 5.2 Display a table showing the distribution of word appearances for each entity type (word count / entity).

ner_counts = books_df['NER'].value_counts()
ner_counts=ner_counts.drop(labels='')
print(ner_counts)
# Out:
# PERSON         4672
# DATE           1490
# ORG            1447
# CARDINAL       1352
# TIME           1200
# GPE             847
# FAC             304
# ORDINAL         272
# WORK_OF_ART     255
# LOC             240
# QUANTITY        188
# NORP            181
# PRODUCT         132
# LAW              89
# LANGUAGE         50
# EVENT            46
# MONEY            24
# Name: NER, dtype: int64

# %%
# 5.3

plt.figure(figsize=(10, 6))
sns.barplot(y=ner_counts.index, x=ner_counts.values, orient='h', color='b', palette='GnBu_r')
plt.title('Most common entity types')
plt.xlabel('Frequency')
plt.ylabel('Entity type')
plt.show()

# %%
# 5.4 Display a table showing the distribution of word appearances for each PoS type (word count / entity).

pos_counts = books_df['PoS'].value_counts()
print(pos_counts)
# Out:
# NOUN     35758
# VERB     30465
# PRON     30425
# ADP      26819
# DET      22203
# SPACE    20630
# ADJ      14322
# AUX      13607
# PROPN    12249
# ADV      12211
# CCONJ     9429
# SCONJ     6297
# PART      5062
# NUM       1732
# INTJ       646
# X           37
# PUNCT        7
# Name: PoS, dtype: int64

# %%
# 5.5

plot = pos_counts.plot.pie(y='mass', figsize=(5, 5))
